# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_bikes.csv') 

train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
sns.pairplot(train)

# %%
train['datetime'] = pd.to_datetime(train['datetime'])
train["year"] = train.datetime.dt.year
train["month"] = train.datetime.dt.month
train["day"] = train.datetime.dt.day
train["hour"] = train.datetime.dt.hour
train["minute"] = train.datetime.dt.minute
train["sec"] = train.datetime.dt.second

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  sec
# 0       0    0
# 1       0    0
# 2       0    0
# ...

# %%
train.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# 10881  19.695        50    26.0027       7         329    336  2012     12
# 10882  17.425        57    15.0013      10         231    241  2012     12
# 10883  15.910        61    15.0013       4         164    168  2012     12
# 10884  17.425        61     6.0032      12         117    129  2012     12
# 10885  16.665        66     8.9981       4          84     88  2012     12
#
#        day  hour  minute  sec
# 10881   19    19       0    0
# ...

# %%
train.year.unique()
# Out:
# array([2011, 2012], dtype=int64)

# %%
train_2011 = train[train["year"]==2011]
train_2012 = train[train["year"] == 2012]

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = "hour",y = "count",hue="workingday",data= train_2011,estimator=sum)
plt.title("2011")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = "hour",y = "count",hue="workingday",data= train_2012,estimator=sum)
plt.title("2012")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = "month",y = "count",hue="year",data= train,estimator=sum)
plt.title("bikes rent per month")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = "hour",y = "count",hue="year",data= train,estimator=sum)
plt.title("bikes rent per hour")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=train_2011,x = "hour",y = "count")
plt.title("bikes rent per hour in 2011")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=train_2012,x = "hour",y = "count")
plt.title("bikes rent per hour in 2012")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=train[train["workingday"]==0],x = "hour",y = "count")
plt.title("bikes rent per hour on working day")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=train[train["workingday"]==1],x = "hour",y = "count")
plt.title("bikes rent per hour on non working day")
plt.show()

# %%
test = pd.read_csv('test_bikes.csv')

# %%
test['datetime'] = pd.to_datetime(test['datetime'])
test["year"] =  test.datetime.dt.year
test["month"] = test.datetime.dt.month
test["day"] = test.datetime.dt.day
test["hour"] = test.datetime.dt.hour
test["minute"] = test.datetime.dt.minute
test["sec"] = test.datetime.dt.second

# %%
test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  hour  minute  sec
# 0        56    26.0027  2011      1   20     0       0    0
# 1        56     0.0000  2011      1   20     1       0    0
# 2        56     0.0000  2011      1   20     2       0    0
# 3        56    11.0014  2011      1   20     3       0    0
# 4        56    11.0014  2011      1   20     4       0    0

# %%
train = train.drop("datetime",axis=1)
test = test.drop("datetime",axis=1)

# %%
plt.figure(figsize=(10,5))
hours = train["count"].groupby(train["hour"]).mean()
hours.plot()
plt.xlabel("hour")
plt.ylabel("average of bikes rent")
plt.show()

# %%
train["count"].groupby(train['temp']).mean().plot()
plt.title("average of bikes rent per vs temperature")
# Out:
# Text(0.5, 1.0, 'average of bikes rent per vs temperature')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x = train.drop(["count"],axis=1)
y = train["count"]
x_train,x_val,y_train,y_val = train_test_split(x,y,test_size=0.2,random_state=32)

# %%
x_train.shape,x_val.shape,y_train.shape,y_val.shape
# Out:
# ((8708, 16), (2178, 16), (8708,), (2178,))

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(x_train)
y_val_pred = model.predict(x_val)

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(y_val, y_val_pred), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_val, y_val_pred), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_val, y_val_pred), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_val, y_val_pred), 2)) 
print("R2 score =", round(sm.r2_score(y_val, y_val_pred), 2))
# Out:
# Mean absolute error = 0.0
# Mean squared error = 0.0
# Median absolute error = 0.0
# Explain variance score = 1.0
# R2 score = 1.0

# %%
y_test = model.predict(x_test)

# %%
y_test
# Out:
# array([110., 107.,  26., ..., 284., 151., 241.])
